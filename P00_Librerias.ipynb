# %% [markdown]
# # Estimación de peso de pollos
#
# ## Colegio de Posgraduados
#
# ### COA661 Inteligencia Artificial
#
# Profesor: Dr. Juan Manuel González Camacho
#
# Entrega: José Alfredo Martínez

# %% [markdown]
# Este notebook instala las librerías necesarias

# %%
# !pip install opencv-python==4.13.0.92

# %%
# !pip install plantcv==4.10.2

# %%
# !pip install scikit-learn==1.7.2

# %%
# !pip install optuna==4.8.0

# %%
# !pip install ISLP
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/16.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.6 MB 5.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.8/16.6 MB 5.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.4/16.6 MB 4.6 MB/s eta 0:00:04
#    -------- ------------------------------- 3.4/16.6 MB 4.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.7/16.6 MB 5.0 MB/s eta 0:00:03
#    -------------- ------------------------- 6.0/16.6 MB 5.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.3/16.6 MB 5.3 MB/s eta 0:00:02
# ...

# %%
#!pip install numpy
#!pip install matplotlib
# !pip install pandas
# !pip install openpyxl
# !pip install joblib
# !pip install seaborn

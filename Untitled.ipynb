# %%
#Librerías
import numpy as np
import pandas as pd
import time

import optuna

from IPython.display import clear_output

from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import sklearn.model_selection
from sklearn.pipeline import Pipeline

import joblib

import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
# Cargar datos
datos1 = pd.read_excel('./misDatos.xlsx', sheet_name = 'X_train')
datos2 = pd.read_excel('./misDatos.xlsx', sheet_name = 'X_test')

fil, col = datos1.shape

X_train = datos1.iloc[:, 0 : col - 1].to_numpy()
Y_train = datos1.iloc[:, col - 1].to_numpy()

X_test = datos2.iloc[:, 0 : col - 1].to_numpy()
Y_test = datos2.iloc[:, col - 1].to_numpy()

# %%
# Estandarizar los datos
scx = StandardScaler()

scx.fit_transform(X_train)
X_train_std = scx.transform(X_train)
X_test_std = scx.transform(X_test)

print(X_train_std.shape)
# Out:
# (2439, 8)

# %%
rango = [2, 5, 10, 20]
#modelo = RandomForestRegressor(random_state = 42)
modelo = RandomForestRegressor(random_state = 42)
train_scores, test_scores = sklearn.model_selection.validation_curve(estimator = modelo, X = X_train, y = Y_train, param_name = 'min_samples_leaf', param_range = rango, cv = 10, scoring = 'r2')

print(train_scores)
# Out:
# [[0.97086744 0.96951656 0.97253161 0.97056115 0.97039901 0.97135708
#   0.9721771  0.97183943 0.97108827 0.97169156]
#  [0.93297826 0.92998242 0.93630985 0.9320813  0.93019882 0.93146152
#   0.93392568 0.93297406 0.93288342 0.93259655]
#  [0.88339138 0.87894933 0.8869026  0.88281945 0.87816777 0.8817799
#   0.88448853 0.8835595  0.8840415  0.88335248]
#  [0.81541478 0.81290758 0.82119086 0.81475679 0.80679585 0.81406245
#   0.81507602 0.81473277 0.81571155 0.81766793]]

# %%
tm = np.mean(train_scores, axis = 1)
ts = np.mean(train_scores, axis = 1)
tem = np.mean(test_scores, axis = 1)
tes = np.mean(test_scores, axis = 1)

plt.plot(rango, tm, marker = 'o')
plt.plot(rango, tem, marker = 's')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

grid = {'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [2, 5, 10, 20],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [2, 5, 10, 20]}
modelo = RandomForestRegressor(random_state = 42)
gs = GridSearchCV(modelo, param_grid = grid, scoring = 'r2', cv = 2)
scores = sklearn.model_selection.cross_val_score(gs, X_train, Y_train, scoring='r2', cv = 5)

print(np.mean(scores), np.std(scores))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 9
#       7 modelo = RandomForestRegressor(random_state = 42)
#       8 gs = GridSearchCV(modelo, param_grid = grid, scoring = 'r2', cv = 2)
# ----> 9 scores = sklearn.model_selection.cross_val_score(gs, X_train, Y_train, scoring='r2', cv = 5)
#      11 print(np.mean(scores), np.std(scores))
#
# File ~\miniconda3\envs\COA501Herramientas\lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
# ...
